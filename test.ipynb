# %%
import json

# %%
crt_dct = {
  "creators": [
    {
      "creator_id": "CR001",
      "name": "Priya's Sustainable Home",
      "platform": "Instagram",
      "handle": "@priyassustainablehome",
      "followers": 145000,
      "engagement_rate": 0.074,
      "avg_views": 22000,
      "content_categories": ["Sustainable Living", "Home Organization", "Zero Waste"],
      "primary_niche": "Eco-Friendly Lifestyle",
      "bio": "Making sustainable living simple for Indian homes 🌱 | Zero waste tips | Mumbai mom of 2 | Reducing plastic one refill at a time",
      "audience_demographics": {
        "age_groups": {
          "25-34": 0.58,
          "35-44": 0.32,
          "45-54": 0.08,
          "18-24": 0.02
        },
        "gender": {
          "female": 0.78,
          "male": 0.20,
          "other": 0.02
        },
        "top_locations": ["Mumbai", "Pune", "Bangalore", "Delhi", "Hyderabad"],
        "income_levels": {
          "upper_middle_class": 0.52,
          "affluent": 0.35,
          "middle_class": 0.13
        }
      },
      "content_themes": [
        "Zero waste home swaps for Indian households",
        "Plastic-free kitchen organization",
        "Eco-friendly cleaning routines",
        "Sustainable parenting tips",
        "Refill culture and waste reduction"
      ],
      "values": [
        "Environmental sustainability",
        "Practical eco-living for families",
        "Chemical-free home",
        "Waste reduction",
        "Conscious consumption"
      ],
      "past_brand_collaborations": [
        "The Better Home",
        "Bare Necessities (zero waste store)",
        "Bombay Greens",
        "Borosil (sustainable cookware)"
      ],
      "posting_frequency": "5-6 posts per week",
      "content_quality_score": 0.88,
      "avg_engagement_per_post": 10730,
      "language": ["Hindi", "English"],
      "tier": "Mid-tier influencer"
    },
    {
      "creator_id": "CR002",
      "name": "FitWithAnkita",
      "platform": "Instagram",
      "handle": "@fitwithankita",
      "followers": 285000,
      "engagement_rate": 0.062,
      "avg_views": 42000,
      "content_categories": ["Fitness", "Healthy Eating", "Weight Loss"],
      "primary_niche": "Health & Fitness",
      "bio": "Certified nutritionist & fitness coach 💪 | Lost 25kg & kept it off | Healthy eating that doesn't suck | Bangalore",
      "audience_demographics": {
        "age_groups": {
          "25-34": 0.54,
          "18-24": 0.24,
          "35-44": 0.18,
          "45-54": 0.04
        },
        "gender": {
          "female": 0.72,
          "male": 0.26,
          "other": 0.02
        },
        "top_locations": ["Bangalore", "Mumbai", "Delhi", "Pune", "Hyderabad"],
        "income_levels": {
          "upper_middle_class": 0.48,
          "middle_class": 0.38,
          "affluent": 0.14
        }
      },
      "content_themes": [
        "Healthy meal prep and recipes",
        "Guilt-free dessert alternatives",
        "Calorie-deficit friendly foods",
        "Home workout routines",
        "Weight loss transformation journey"
      ],
      "values": [
        "Sustainable weight loss",
        "Balance over restriction",
        "Healthy relationship with food",
        "Body positivity",
        "Science-based fitness"
      ],
      "past_brand_collaborations": [
        "HealthifyMe",
        "MyFitnessPal India",
        "Yoga Bar",
        "Fit & Flex"
      ],
      "posting_frequency": "Daily posts",
      "content_quality_score": 0.85,
      "avg_engagement_per_post": 17670,
      "language": ["English", "Hindi"],
      "tier": "Mid-tier influencer"
    },
    {
      "creator_id": "CR003",
      "name": "HealthyKitchenDiaries",
      "platform": "YouTube",
      "handle": "@healthykitchendiaries",
      "followers": 320000,
      "engagement_rate": 0.048,
      "avg_views": 58000,
      "content_categories": ["Healthy Cooking", "Recipes", "Nutrition"],
      "primary_niche": "Healthy Food & Cooking",
      "bio": "Home chef making Indian food healthy 🍛 | Sugar-free recipes | PCOS warrior sharing what works | Delhi-based",
      "audience_demographics": {
        "age_groups": {
          "25-34": 0.48,
          "35-44": 0.32,
          "18-24": 0.14,
          "45-54": 0.06
        },
        "gender": {
          "female": 0.82,
          "male": 0.16,
          "other": 0.02
        },
        "top_locations": ["Delhi", "Noida", "Mumbai", "Bangalore", "Gurgaon"],
        "income_levels": {
          "upper_middle_class": 0.52,
          "middle_class": 0.32,
          "affluent": 0.16
        }
      },
      "content_themes": [
        "Sugar-free Indian desserts",
        "PCOS-friendly recipes",
        "Diabetic-friendly cooking",
        "Healthy Indian meal prep",
        "Traditional recipes made healthier"
      ],
      "values": [
        "Making healthy accessible",
        "No deprivation diets",
        "Indian food can be healthy",
        "Evidence-based nutrition",
        "Taste without compromise"
      ],
      "past_brand_collaborations": [
        "Keto India",
        "True Elements",
        "Dr. Vaidya's",
        "Raw Pressery"
      ],
      "posting_frequency": "3-4 videos per week",
      "content_quality_score": 0.90,
      "avg_engagement_per_post": 15360,
      "language": ["Hindi", "English"],
      "tier": "Mid-tier influencer"
    },
    {
      "creator_id": "CR004",
      "name": "MomLifeWithMeera",
      "platform": "Instagram",
      "handle": "@momlifewithmeera",
      "followers": 195000,
      "engagement_rate": 0.069,
      "avg_views": 28000,
      "content_categories": ["Parenting", "Home Management", "Family Life"],
      "primary_niche": "Mom & Family Content",
      "bio": "Mom of 3 | Home organization hacks | Chemical-free parenting | Making mom life easier in Mumbai 💕",
      "audience_demographics": {
        "age_groups": {
          "25-34": 0.52,
          "35-44": 0.38,
          "45-54": 0.08,
          "18-24": 0.02
        },
        "gender": {
          "female": 0.88,
          "male": 0.10,
          "other": 0.02
        },
        "top_locations": ["Mumbai", "Pune", "Delhi", "Bangalore", "Ahmedabad"],
        "income_levels": {
          "upper_middle_class": 0.48,
          "affluent": 0.32,
          "middle_class": 0.20
        }
      },
      "content_themes": [
        "Kid-safe cleaning products",
        "Home organization for families",
        "Parenting hacks and tips",
        "Allergy-free home management",
        "Working mom routines"
      ],
      "values": [
        "Family health and safety",
        "Practical parenting",
        "Chemical-free living",
        "Organization and efficiency",
        "Mental wellness for moms"
      ],
      "past_brand_collaborations": [
        "FirstCry",
        "Mamaearth",
        "Himalaya Baby",
        "Pigeon India"
      ],
      "posting_frequency": "4-5 posts per week",
      "content_quality_score": 0.84,
      "avg_engagement_per_post": 13455,
      "language": ["Hindi", "English"],
      "tier": "Mid-tier influencer"
    },
    {
      "creator_id": "CR005",
      "name": "DiabetesFreeLife",
      "platform": "Instagram",
      "handle": "@diabetesfreelife",
      "followers": 165000,
      "engagement_rate": 0.076,
      "avg_views": 26000,
      "content_categories": ["Diabetes Management", "Health", "Nutrition"],
      "primary_niche": "Diabetes & Lifestyle Diseases",
      "bio": "Reversed my diabetes naturally 📊 | Sharing sugar-free living tips | Certified diabetes educator | Helping 10K+ Indians",
      "audience_demographics": {
        "age_groups": {
          "35-44": 0.42,
          "25-34": 0.28,
          "45-54": 0.22,
          "55-64": 0.08
        },
        "gender": {
          "male": 0.52,
          "female": 0.46,
          "other": 0.02
        },
        "top_locations": ["Delhi", "Mumbai", "Hyderabad", "Chennai", "Bangalore"],
        "income_levels": {
          "upper_middle_class": 0.52,
          "middle_class": 0.32,
          "affluent": 0.16
        }
      },
      "content_themes": [
        "Sugar-free food alternatives",
        "Blood sugar management tips",
        "Diabetes-friendly recipes",
        "Lifestyle disease reversal",
        "Product reviews for diabetics"
      ],
      "values": [
        "Natural diabetes management",
        "Education and awareness",
        "Sustainable lifestyle changes",
        "Evidence-based health",
        "Community support"
      ],
      "past_brand_collaborations": [
        "Sugar Free",
        "Apollo Pharmacy",
        "Diabeto Care",
        "Wellthy Care"
      ],
      "posting_frequency": "5-6 posts per week",
      "content_quality_score": 0.87,
      "avg_engagement_per_post": 12540,
      "language": ["Hindi", "English"],
      "tier": "Mid-tier influencer"
    },
    {
      "creator_id": "CR006",
      "name": "CleanHomeSimplified",
      "platform": "YouTube",
      "handle": "@cleanhomesimplified",
      "followers": 128000,
      "engagement_rate": 0.082,
      "avg_views": 24000,
      "content_categories": ["Home Cleaning", "Organization", "Home Care"],
      "primary_niche": "Home Care & Cleaning",
      "bio": "Professional home organizer 🏠 | Deep cleaning tutorials | Product reviews | Making Indian homes sparkle",
      "audience_demographics": {
        "age_groups": {
          "25-34": 0.44,
          "35-44": 0.38,
          "45-54": 0.14,
          "18-24": 0.04
        },
        "gender": {
          "female": 0.76,
          "male": 0.22,
          "other": 0.02
        },
        "top_locations": ["Bangalore", "Mumbai", "Pune", "Hyderabad", "Chennai"],
        "income_levels": {
          "middle_class": 0.42,
          "upper_middle_class": 0.48,
          "affluent": 0.10
        }
      },
      "content_themes": [
        "Deep cleaning tutorials",
        "Cleaning product comparisons",
        "Kitchen organization hacks",
        "Bathroom and toilet cleaning",
        "Stain removal techniques"
      ],
      "values": [
        "Clean home, happy life",
        "Efficiency in cleaning",
        "Product effectiveness",
        "Home aesthetics",
        "Practical tips"
      ],
      "past_brand_collaborations": [
        "Vim",
        "Harpic",
        "Surf Excel",
        "Amazon Basics"
      ],
      "posting_frequency": "3 videos per week",
      "content_quality_score": 0.83,
      "avg_engagement_per_post": 10496,
      "language": ["Hindi", "English"],
      "tier": "Micro influencer"
    },
    {
      "creator_id": "CR007",
      "name": "FitnessWithRohan",
      "platform": "Instagram",
      "handle": "@fitnessrohanbatra",
      "followers": 420000,
      "engagement_rate": 0.055,
      "avg_views": 68000,
      "content_categories": ["Fitness", "Bodybuilding", "Nutrition"],
      "primary_niche": "Fitness & Gym",
      "bio": "Certified personal trainer | Transformation coach | 100+ clients transformed | Supplements & nutrition | Delhi",
      "audience_demographics": {
        "age_groups": {
          "18-24": 0.38,
          "25-34": 0.45,
          "35-44": 0.14,
          "45-54": 0.03
        },
        "gender": {
          "male": 0.72,
          "female": 0.26,
          "other": 0.02
        },
        "top_locations": ["Delhi", "Gurgaon", "Mumbai", "Noida", "Bangalore"],
        "income_levels": {
          "middle_class": 0.48,
          "upper_middle_class": 0.38,
          "affluent": 0.14
        }
      },
      "content_themes": [
        "Workout routines and form",
        "Muscle building diet plans",
        "Supplement reviews",
        "Body transformation journeys",
        "Gym equipment recommendations"
      ],
      "values": [
        "Discipline and hard work",
        "Science-based training",
        "Natural bodybuilding",
        "Consistency over perfection",
        "Community motivation"
      ],
      "past_brand_collaborations": [
        "MuscleBlaze",
        "Cult.fit",
        "MyProtein India",
        "Gym Beam India"
      ],
      "posting_frequency": "Daily posts",
      "content_quality_score": 0.81,
      "avg_engagement_per_post": 23100,
      "language": ["Hindi", "English"],
      "tier": "Mid-tier influencer"
    },
    {
      "creator_id": "CR008",
      "name": "GreenLivingNaina",
      "platform": "Instagram",
      "handle": "@greenlivingnaina",
      "followers": 178000,
      "engagement_rate": 0.071,
      "avg_views": 27000,
      "content_categories": ["Sustainability", "Eco-Living", "Zero Waste"],
      "primary_niche": "Sustainable Lifestyle",
      "bio": "🌱 Eco warrior | Zero waste living in Indian cities | Sustainable swaps | Vegan lifestyle | Reducing my carbon footprint",
      "audience_demographics": {
        "age_groups": {
          "25-34": 0.56,
          "18-24": 0.24,
          "35-44": 0.16,
          "45-54": 0.04
        },
        "gender": {
          "female": 0.74,
          "male": 0.24,
          "other": 0.02
        },
        "top_locations": ["Bangalore", "Pune", "Mumbai", "Delhi", "Goa"],
        "income_levels": {
          "upper_middle_class": 0.52,
          "affluent": 0.32,
          "middle_class": 0.16
        }
      },
      "content_themes": [
        "Zero waste home swaps",
        "Sustainable fashion and thrifting",
        "Eco-friendly product reviews",
        "Plastic-free living",
        "Vegan lifestyle tips"
      ],
      "values": [
        "Environmental conservation",
        "Conscious consumption",
        "Climate action",
        "Minimalism",
        "Animal welfare"
      ],
      "past_brand_collaborations": [
        "H&M Conscious Collection",
        "Westside Slow Fashion",
        "FabIndia Organic",
        "Myntra Eco Edit"
      ],
      "posting_frequency": "5-6 posts per week",
      "content_quality_score": 0.86,
      "avg_engagement_per_post": 12638,
      "language": ["English", "Hindi"],
      "tier": "Mid-tier influencer",
      "notes": "RED FLAG: Claims eco-consciousness but has partnered with H&M and Myntra (fast fashion)"
    },
    {
      "creator_id": "CR009",
      "name": "PCOSWarriorPreeti",
      "platform": "Instagram",
      "handle": "@pcoswarriorpreeti",
      "followers": 142000,
      "engagement_rate": 0.085,
      "avg_views": 24000,
      "content_categories": ["PCOS", "Women's Health", "Nutrition"],
      "primary_niche": "PCOS & Hormonal Health",
      "bio": "Reversed PCOS naturally 💪 | Nutritionist | Sugar-free recipes for hormonal health | Helping women take control",
      "audience_demographics": {
        "age_groups": {
          "25-34": 0.62,
          "18-24": 0.22,
          "35-44": 0.14,
          "45-54": 0.02
        },
        "gender": {
          "female": 0.94,
          "male": 0.04,
          "other": 0.02
        },
        "top_locations": ["Mumbai", "Delhi", "Bangalore", "Pune", "Hyderabad"],
        "income_levels": {
          "upper_middle_class": 0.48,
          "middle_class": 0.38,
          "affluent": 0.14
        }
      },
      "content_themes": [
        "PCOS-friendly recipes and meal plans",
        "Hormonal health education",
        "Sugar-free desserts for PCOS",
        "Lifestyle management for PCOS",
        "Supplement and nutrition guidance"
      ],
      "values": [
        "Natural healing",
        "Women's empowerment",
        "Evidence-based health",
        "Community support",
        "Body positivity"
      ],
      "past_brand_collaborations": [
        "Veera Health",
        "Gynoveda",
        "Organic India",
        "Nutriberg"
      ],
      "posting_frequency": "4-5 posts per week",
      "content_quality_score": 0.89,
      "avg_engagement_per_post": 12070,
      "language": ["English", "Hindi"],
      "tier": "Mid-tier influencer"
    },
    {
      "creator_id": "CR010",
      "name": "TheFoodieNutritionist",
      "platform": "Instagram",
      "handle": "@thefoodienutritionist",
      "followers": 235000,
      "engagement_rate": 0.064,
      "avg_views": 38000,
      "content_categories": ["Food", "Nutrition", "Healthy Eating"],
      "primary_niche": "Food & Nutrition",
      "bio": "Nutritionist who loves food 🍰 | Healthy eating without boring meals | Recipe developer | Mumbai-based foodie",
      "audience_demographics": {
        "age_groups": {
          "25-34": 0.52,
          "18-24": 0.28,
          "35-44": 0.16,
          "45-54": 0.04
        },
        "gender": {
          "female": 0.68,
          "male": 0.30,
          "other": 0.02
        },
        "top_locations": ["Mumbai", "Delhi", "Bangalore", "Pune", "Kolkata"],
        "income_levels": {
          "upper_middle_class": 0.52,
          "affluent": 0.32,
          "middle_class": 0.16
        }
      },
      "content_themes": [
        "Healthy restaurant finds",
        "Recipe development and testing",
        "Nutrition myths debunked",
        "Balanced eating approach",
        "Food photography and styling"
      ],
      "values": [
        "Balance over restriction",
        "Food is meant to be enjoyed",
        "Science-based nutrition",
        "No diet culture",
        "Quality ingredients"
      ],
      "past_brand_collaborations": [
        "Zomato",
        "Swiggy",
        "Nourish Organics",
        "Epigamia"
      ],
      "posting_frequency": "Daily posts",
      "content_quality_score": 0.87,
      "avg_engagement_per_post": 15040,
      "language": ["English", "Hindi"],
      "tier": "Mid-tier influencer"
    }
  ]
}

# %%
print(crt_dct["creators"][0])
# Out:
# {'creator_id': 'CR001', 'name': "Priya's Sustainable Home", 'platform': 'Instagram', 'handle': '@priyassustainablehome', 'followers': 145000, 'engagement_rate': 0.074, 'avg_views': 22000, 'content_categories': ['Sustainable Living', 'Home Organization', 'Zero Waste'], 'primary_niche': 'Eco-Friendly Lifestyle', 'bio': 'Making sustainable living simple for Indian homes 🌱 | Zero waste tips | Mumbai mom of 2 | Reducing plastic one refill at a time', 'audience_demographics': {'age_groups': {'25-34': 0.58, '35-44': 0.32, '45-54': 0.08, '18-24': 0.02}, 'gender': {'female': 0.78, 'male': 0.2, 'other': 0.02}, 'top_locations': ['Mumbai', 'Pune', 'Bangalore', 'Delhi', 'Hyderabad'], 'income_levels': {'upper_middle_class': 0.52, 'affluent': 0.35, 'middle_class': 0.13}}, 'content_themes': ['Zero waste home swaps for Indian households', 'Plastic-free kitchen organization', 'Eco-friendly cleaning routines', 'Sustainable parenting tips', 'Refill culture and waste reduction'], 'values': ['Environmenta
# ...

# %%
brd_dct = {
  "brands": [
    {
      "brand_id": "BR001",
      "brand_name": "Happi Planet",
      "industry": "Eco-Friendly Home Care Products",
      "company_size": "Startup (20-50 employees)",
      "founded": 2020,
      "website": "https://www.happi-planet.com/",
      "description": "Happi Planet creates effective, eco-friendly home care products powered by nature. From plant-based detergents to natural floor cleaners, we're making sustainable cleaning accessible for Indian households. Our products are tough on stains but gentle on skin and the planet.",
      "target_audience": {
        "age_range": "25-45",
        "primary_gender": "Female (70%), Male (30%)",
        "locations": ["Mumbai", "Pune", "Bangalore", "Delhi NCR", "Tier 1 cities"],
        "income_level": "Upper Middle Class (₹8L-₹20L annual income)",
        "interests": [
          "Sustainable living and eco-consciousness",
          "Home care and organization",
          "Natural and chemical-free products",
          "Family health and safety",
          "Environmental responsibility"
        ],
        "psychographics": "Urban Indian families who want effective cleaning without harmful chemicals. Concerned about skin allergies, environmental impact, and family health. Value transparency in ingredients. Willing to pay premium for sustainable products that actually work."
      },
      "brand_values": [
        "Powered by nature, not chemicals",
        "Effective cleaning without compromising safety",
        "Plastic waste reduction",
        "Skin-safe and allergy-friendly",
        "Transparency in ingredients"
      ],
      "unique_selling_points": [
        "India's 1st foaming formulation for less scrubbing",
        "Plant-based, biodegradable formulas",
        "Refill pods to reduce plastic waste by 80%",
        "Gentle on skin - no rashes or allergies",
        "Works as well as chemical cleaners",
        "Safe for homes with kids and pets"
      ],
      "campaign_goals": {
        "primary_objective": "Increase brand awareness among eco-conscious urban families",
        "secondary_objective": "Drive trial of refill pod system and reduce plastic usage",
        "campaign_type": "Product education + lifestyle integration + sustainability messaging",
        "key_messages": [
          "Effective cleaning doesn't need harsh chemicals",
          "Switch to sustainable without compromising performance",
          "Safe for your family, kind to the planet"
        ],
        "target_metrics": {
          "reach": "1.5-2 million impressions",
          "engagement": "40,000+ engaged users",
          "conversions": "3,000+ first-time purchases via creator codes"
        }
      },
      "creator_preferences": {
        "follower_range": "80K-350K (micro to mid-tier influencers)",
        "engagement_priority": "High engagement and authentic community critical",
        "content_authenticity": "Must genuinely care about sustainability and show actual product usage in daily life",
        "platforms": ["Instagram", "YouTube"],
        "content_style": "Authentic home content, educational, family-focused, sustainability angle, before/after cleaning demos",
        "niche_alignment": [
          "Sustainable living and zero waste",
          "Home organization and cleaning",
          "Mom bloggers and family content",
          "Eco-conscious lifestyle",
          "Health and wellness (chemical-free living angle)"
        ],
        "language_preference": "Bilingual Hindi + English preferred for urban reach",
        "must_avoid": [
          "Luxury lifestyle without sustainability focus",
          "Creators promoting chemical cleaning brands",
          "Overly aspirational without relatability",
          "Beauty-only content without home care angle"
        ]
      },
      "budget": {
        "campaign_budget": "₹25,00,000",
        "per_creator_range": "₹1,00,000 - ₹5,00,000",
        "number_of_creators": "6-8 creators",
        "product_seeding_budget": "₹3,00,000"
      },
      "past_successful_partnerships": [
        "Mom influencers showing family-safe cleaning",
        "Sustainability advocates with home care focus",
        "Home organization creators",
        "Health-conscious family content creators"
      ],
      "avoid_partnerships_with": [
        "Creators promoting single-use plastics",
        "Chemical cleaning brand ambassadors",
        "Pure luxury lifestyle without eco angle",
        "Creators without family/home content"
      ],
      "brand_voice": "Friendly, educational, empowering, relatable, slightly playful but informative",
      "content_guidelines": {
        "must_include": [
          "Actual product usage in daily home routine",
          "Before/after cleaning demonstrations",
          "Ingredient transparency and safety messaging",
          "Refill pod system and plastic reduction angle",
          "Family/pet safety emphasis"
        ],
        "must_avoid": [
          "Overly scientific or preachy tone",
          "Guilt-tripping about environmental choices",
          "Luxury home aesthetics only",
          "Claims without demonstrations"
        ]
      },
      "indian_market_context": {
        "challenges": [
          "Price sensitivity - need to justify premium",
          "Trust in natural products' effectiveness",
          "Behavioral change from chemical cleaners"
        ],
        "opportunities": [
          "Growing skin allergy concerns",
          "Rising eco-consciousness in metros",
          "Mothers seeking safer products for kids"
        ]
      }
    },
    {
      "brand_id": "BR002",
      "brand_name": "Upside Health",
      "industry": "Healthy Desserts & Snacks",
      "company_size": "Startup (30-60 employees)",
      "founded": 2021,
      "website": "https://upsidehealth.in/",
      "description": "Upside Health is revolutionizing Indian desserts and snacks with no added sugar, no gluten, and no compromise on taste. From guilt-free Tiramisu to protein-rich Laddoos, we're proving that healthy can be delicious. Real ingredients, real taste, zero guilt.",
      "target_audience": {
        "age_range": "25-45",
        "primary_gender": "Female (60%), Male (40%)",
        "locations": ["Mumbai", "Pune", "Bangalore", "Delhi NCR", "Hyderabad", "Tier 1 cities"],
        "income_level": "Upper Middle Class to Affluent (₹10L-₹30L+ annual income)",
        "interests": [
          "Health and fitness",
          "Nutrition and wellness",
          "Diabetes management and prevention",
          "Weight management",
          "Food and culinary experiences",
          "Premium quality products"
        ],
        "psychographics": "Health-conscious urban Indians who refuse to compromise on taste. Fitness enthusiasts, diabetics, PCOS/thyroid patients, and calorie-conscious individuals who still crave desserts. Value premium quality, willing to pay 2-3x regular prices for genuinely healthy alternatives."
      },
      "brand_values": [
        "Taste without compromise",
        "No BS ingredients - truly healthy",
        "Transparency in nutrition",
        "Guilt-free indulgence",
        "Quality over everything"
      ]
      ,
      "unique_selling_points": [
        "No added sugar, sweetened with dates/jaggery/stevia",
        "No gluten, no preservatives, no seed oils",
        "High in protein and fiber",
        "Low refined carbs",
        "Actually tastes good (not cardboard)",
        "Premium desserts: Tiramisu, Brownies, Cheesecake, Mithai",
        "Made fresh in Mumbai, delivered across India"
      ],
      "campaign_goals": {
        "primary_objective": "Drive online orders and subscriptions for desserts and mithai",
        "secondary_objective": "Position as THE premium healthy dessert brand in India",
        "campaign_type": "Taste proof + lifestyle aspiration + educational content",
        "key_messages": [
          "Your cravings deserve better",
          "Healthy doesn't mean tasteless",
          "Desserts that love you back"
        ],
        "target_metrics": {
          "reach": "2-3 million impressions",
          "engagement": "60,000+ engaged users",
          "conversions": "2,500+ orders via creator discount codes",
          "repeat_rate": "30% repeat purchase within 60 days"
        }
      },
      "creator_preferences": {
        "follower_range": "120K-500K (mid-tier influencers with established credibility)",
        "engagement_priority": "Balance of reach and engagement - need conversion potential",
        "content_authenticity": "Must demonstrate actual healthy lifestyle - gym content, meal prep, wellness journey",
        "platforms": ["Instagram", "YouTube"],
        "content_style": "Aspirational yet authentic, educational, food porn worthy, fitness integration, honest taste reviews",
        "niche_alignment": [
          "Fitness and health (with food angle)",
          "Healthy cooking and meal prep",
          "Diabetes/PCOS/thyroid management",
          "Weight loss journeys",
          "Food bloggers (healthy/conscious eating)",
          "Mom bloggers (healthy kids snacks)"
        ],
        "language_preference": "Primarily English + Hindi for metro audience",
        "must_avoid": [
          "Junk food promoters or inconsistent health messaging",
          "Extreme diet advocates (keto-only, carnivore, etc.)",
          "Creators without genuine health interest",
          "Pure aesthetics without substance"
        ]
      },
      "budget": {
        "campaign_budget": "₹40,00,000",
        "per_creator_range": "₹2,50,000 - ₹10,00,000",
        "number_of_creators": "5-7 creators",
        "performance_bonus": "20% additional for meeting sales targets",
        "affiliate_commission": "12% on all orders from creator codes"
      },
      "past_successful_partnerships": [
        "Fitness influencers who share cheat meal alternatives",
        "Health-focused food bloggers",
        "PCOS/diabetes management content creators",
        "Lifestyle creators with wellness focus"
      ],
      "avoid_partnerships_with": [
        "Pure bodybuilding/supplement focus",
        "Junk food content creators",
        "Fad diet promoters",
        "Creators without visible health practices",
        "Beauty-only content without health angle"
      ],
      "brand_voice": "Honest, aspirational but achievable, slightly cheeky, premium but relatable, unapologetically quality-focused",
      "content_guidelines": {
        "must_include": [
          "Honest taste reviews (acknowledge it's premium/different)",
          "Unboxing and product showcasing",
          "Integration in fitness/health routines",
          "Comparison with traditional desserts (nutrition facts)",
          "Occasion-based usage (festivals, celebrations, cravings)"
        ],
        "must_avoid": [
          "Weight loss guarantees or medical claims",
          "Comparison that bashes traditional desserts",
          "Overly clinical or boring presentation",
          "Hiding the premium pricing"
        ]
      },
      "indian_market_context": {
        "challenges": [
          "High price point vs traditional mithai",
          "Taste skepticism for healthy desserts",
          "Limited delivery geography (Mumbai/Pune focus)"
        ],
        "opportunities": [
          "Rising diabetes and lifestyle diseases",
          "Fitness culture boom in metros",
          "Festival season gifting",
          "Corporate gifting potential"
        ]
      },
      "special_requirements": {
        "product_samples": "Must send product samples for genuine reviews",
        "content_approval": "Taste/nutrition claims must be pre-approved",
        "exclusivity": "No promotion of direct competitor healthy dessert brands during campaign + 2 months"
      }
    }
  ]
}

# %%
print(brd_dct["brands"][0])
# Out:
# {'brand_id': 'BR001', 'brand_name': 'Happi Planet', 'industry': 'Eco-Friendly Home Care Products', 'company_size': 'Startup (20-50 employees)', 'founded': 2020, 'website': 'https://www.happi-planet.com/', 'description': "Happi Planet creates effective, eco-friendly home care products powered by nature. From plant-based detergents to natural floor cleaners, we're making sustainable cleaning accessible for Indian households. Our products are tough on stains but gentle on skin and the planet.", 'target_audience': {'age_range': '25-45', 'primary_gender': 'Female (70%), Male (30%)', 'locations': ['Mumbai', 'Pune', 'Bangalore', 'Delhi NCR', 'Tier 1 cities'], 'income_level': 'Upper Middle Class (₹8L-₹20L annual income)', 'interests': ['Sustainable living and eco-consciousness', 'Home care and organization', 'Natural and chemical-free products', 'Family health and safety', 'Environmental responsibility'], 'psychographics': 'Urban Indian families who want effective cleaning without harmful ch
# ...

# %%
with open(r"D:\Project\assignment\brands.json",encoding="utf-8") as f:
    brands = json.load(f)
